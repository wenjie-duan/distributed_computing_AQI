# %%
import seaborn as sns
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
feature_importance_by_day = np.array([5.77284703e-01, 2.49838686e-01, 5.18767390e-02, 6.45854578e-03,
       1.99192895e-03, 8.75694903e-03, 2.61893183e-02, 9.14167915e-03,
       4.18156314e-03, 7.89270496e-03, 3.00424150e-03, 1.47859132e-03,
       2.43310459e-03, 3.98974694e-03, 1.94787620e-02, 1.98895708e-03,
       1.62192141e-03, 1.08964079e-03, 2.96401791e-03, 2.52663410e-03,
       4.15012997e-03, 2.97988435e-03, 6.77109610e-04, 2.01949257e-04,
       1.11550920e-03, 1.35900105e-03, 1.29467302e-03, 1.24269696e-03,
       1.54390655e-03, 1.24670560e-03])

# %%
feature_importance_name = ['prev1', 'prev2', 'prev3', 'prev4', 'prev5', 'prev6', 'prev7', 'prev8', 'prev9', 'prev10', 'prev11', 'prev12', 'prev13', 'prev14', 'prev15', 'prev16', 'prev17', 'prev18', 'prev19', 'prev20', 'prev21', 'prev22', 'prev23', 'prev24', 'prev25', 'prev26', 'prev27', 'prev28', 'prev29', 'prev30']

# %%
df_by_day = pd.DataFrame({"name":feature_importance_name,"importance":feature_importance_by_day})

# %%
df_by_day
# Out:
#       name  importance
# 0    prev1    0.577285
# 1    prev2    0.249839
# 2    prev3    0.051877
# 3    prev4    0.006459
# 4    prev5    0.001992
# 5    prev6    0.008757
# 6    prev7    0.026189
# 7    prev8    0.009142
# 8    prev9    0.004182
# 9   prev10    0.007893
# 10  prev11    0.003004
# 11  prev12    0.001479
# 12  prev13    0.002433
# 13  prev14    0.003990
# 14  prev15    0.019479
# 15  prev16    0.001989
# 16  prev17    0.001622
# 17  prev18    0.001090
# 18  prev19    0.002964
# 19  prev20    0.002527
# 20  prev21    0.004150
# 21  prev22    0.002980
# 22  prev23    0.000677
# 23  prev24    0.000202
# 24  prev25    0.001116
# 25  prev26    0.001359
# 26  prev27    0.001295
# 27  prev28    0.001243
# 28  prev29    0.001544
# 29  prev30    0.001247

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize=(20,8))
ax = sns.barplot(data=df_by_day, x = "name", y="importance")

# %%
la_dl_records = [('prev1', 1.0, 1.0, 0.07227789655504101), ('month', 0.6569347381591797, 0.6569347381591797, 0.047481861048082136), ('year', 0.4375078082084656, 0.4375078082084656, 0.031622144103714195), ('imputed_temp', 0.4111132323741913, 0.4111132323741913, 0.029714399681950332), ('prev2', 0.3782954514026642, 0.3782954514026642, 0.0273423995037243), ('imputed_wind_speed', 0.3734728693962097, 0.3734728693962097, 0.026993833420333586), ('dow', 0.36343061923980713, 0.36343061923980713, 0.026268000702349272), ('prev6', 0.3521289527416229, 0.3521289527416229, 0.025451140020293944), ('imputed_wind_direction', 0.34840127825737, 0.34840127825737, 0.025181711549530243), ('day', 0.34743475914001465, 0.34743475914001465, 0.025111853580747565), ('prev23', 0.34416112303733826, 0.34416112303733826, 0.024875242049159474), ('prev27', 0.33792874217033386, 0.33792874217033386, 0.024424778669562514), ('prev29', 0.3345054090023041, 0.3345054090023041, 0.024177347348970216), ('imputed_humidity', 0.33197420835494995, 0.33197420835494995, 0.0239943974904207), ('prev16', 0.3315383791923523, 0.3315383791923523, 0.023962896675290796), ('imputed_pressure', 0.3310353755950928, 0.3310353755950928, 0.02392654063332126), ('prev9', 0.3305465281009674, 0.3305465281009674, 0.023891207764709675), ('prev7', 0.3286016583442688, 0.3286016583442688, 0.023750636669621985), ('prev22', 0.3282966911792755, 0.3282966911792755, 0.02372859428441792), ('prev3', 0.3276236653327942,
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.3276236653327942, 0.02367994939190707), ('prev14', 0.3229432702064514, 0.3229432702064514, 0.02334166027712855), ('prev19', 0.31997886300086975, 0.31997886300086975, 0.0231273991597765), ('prev4', 0.31944870948791504, 0.31944870948791504, 0.02308908077900887), ('prev20', 0.3190993666648865, 0.3190993666648865, 0.023063831014583765), ('prev24', 0.31867456436157227, 0.31867456436157227, 0.023033127197648478), ('prev5', 0.3170122802257538, 0.3170122802257538, 0.022912980796834702), ('prev10', 0.31479597091674805, 0.31479597091674805, 0.022752790621864413), ('prev28', 0.31352514028549194, 0.31352514028549194, 0.022660937656959507), ('prev8', 0.3129037022590637, 0.3129037022590637, 0.022616021423569957), ('prev30', 0.3111586570739746, 0.3111586570739746, 0.022489893228198214), ('prev13', 0.30946993827819824, 0.30946993827819824, 0.022367836185766536), ('prev11', 0.3088553547859192, 0.3088553547859192, 0.022323415383687154), ('prev21', 0.304017573595047, 0.304017573595047, 0.021973750735217373), ('prev17', 0.30091848969459534, 0.30091848969459534, 0.021749755469645134), ('prev26', 0.3003886044025421, 0.3003886044025421, 0.021711456475320072), ('prev25', 0.28981924057006836, 0.28981924057006836, 0.020947525089583943), ('prev12', 0.2896442711353302, 0.2896442711353302, 0.020934878666879646), ('prev15', 0.2877579927444458, 0.2877579927444458, 0.020798542432469293), ('prev18', 0.28014492988586426, 0.28014492988586426, 0.020248286262709712)]

# %%
la_dl = pd.DataFrame.from_records(la_dl_records)

# %%
la_dl = la_dl.rename(columns={0:"variable",1: "relative_importance", 2: "scaled_importance",3:"percentage"})

# %%
la_dl
# Out:
#                   variable  relative_importance  scaled_importance  percentage
# 0                    prev1             1.000000           1.000000    0.072278
# 1                    month             0.656935           0.656935    0.047482
# 2                     year             0.437508           0.437508    0.031622
# 3             imputed_temp             0.411113           0.411113    0.029714
# 4                    prev2             0.378295           0.378295    0.027342
# 5       imputed_wind_speed             0.373473           0.373473    0.026994
# 6                      dow             0.363431           0.363431    0.026268
# 7                    prev6             0.352129           0.352129    0.025451
# 8   imputed_wind_direction             0.348401           0.348401    0.025182
# 9                      day             0.347435           0.347435    0.025112
# 10                  prev23             0.344161           0.344161    0.024875
# ...

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(data=la_dl, x = "relative_importance", y="variable")

# %%
all_dl_records = [('pressure', 1.0, 1.0, 0.24352833540789529), ('wind_speed', 0.49859076738357544, 0.49859076738357544, 0.12142097963066727), ('County_Code_num', 0.3483409583568573, 0.3483409583568573, 0.08483089374303643), ('temp', 0.31487762928009033, 0.31487762928009033, 0.07668162491576475), ('wind_direction', 0.2978503108024597, 0.2978503108024597, 0.07253499039044727), ('State_Code_num', 0.2913719117641449, 0.2913719117641449, 0.07095731665653836), ('humidity', 0.26199865341186523, 0.26199865341186523, 0.06380409594450162), ('year', 0.24647609889507294, 0.24647609889507294, 0.06002391408174889), ('month', 0.24184292554855347, 0.24184292554855347, 0.05889560508901478), ('prev1_AQI', 0.19858261942863464, 0.19858261942863464, 0.048360494750394965), ('prev2_AQI', 0.12196200340986252, 0.12196200340986252, 0.029701203673415867), ('prev3_AQI', 0.11005360633134842, 0.11005360633134842, 0.026801171555509085), ('dow', 0.09128127247095108, 0.09128127247095108, 0.022229576338765253), ('day', 0.0830695852637291, 0.0830695852637291, 0.020229797822300177)]

# %%
all_dl = pd.DataFrame.from_records(all_dl_records)

# %%
all_dl = all_dl.rename(columns={0:"variable",1: "relative_importance", 2: "scaled_importance",3:"percentage"})

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(data=all_dl, x = "percentage", y="variable")

# %%
MAE = [24.67,25.30, 22.05, 12.3,11.8, 12.5]
RMSE = [32.93, 33.76, 29.56, 20.7, 19.2, 19.0]
NAME = ["Spark RF: Previous 30 days AQI",
        "Spark RF: Previous AQI + Date+Weather",
        "H2O DL: Previous AQI + Date+Weather",
        "H2O DL: Date+Weather+Previous 1 day AQI ",
        "H2O DL: Date+Weather+Previous 3 days AQI",
        "H2O DL: Date+Weather+Previous 3 days AQI (LA county)"]

# %%
performance = pd.DataFrame({'NAME':NAME,
                            'MAE' : MAE,
                            'RMSE' : RMSE})

# %%
performance
# Out:
#                                                 NAME    MAE   RMSE
# 0                     Spark RF: Previous 30 days AQI  24.67  32.93
# 1              Spark RF: Previous AQI + Date+Weather  25.30  33.76
# 2                H2O DL: Previous AQI + Date+Weather  22.05  29.56
# 3           H2O DL: Date+Weather+Previous 1 day AQI   12.30  20.70
# 4           H2O DL: Date+Weather+Previous 3 days AQI  11.80  19.20
# 5  H2O DL: Date+Weather+Previous 3 days AQI (LA c...  12.50  19.00

# %%
plt.figure(figsize=(15,8))
ax = sns.lineplot(data=performance, x = "NAME", y="MAE", hue = "RMSE")

# %%
# multiple line plot
plt.figure(figsize=(16,10))
plt.plot( 'NAME', 'MAE', data=performance, marker='o',linewidth=7.0)
plt.plot( 'NAME', 'RMSE', data=performance, marker='.', linewidth = 7.0)
# plt.axvspan(2.7, 5, color='grey', alpha=0.3, lw=0)
plt.xticks(x = NAME,rotation=20,size = 25)
plt.yticks(size = 25)
#plt.plot( 'x', 'y3', data=performance, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.legend(prop={'size': 30})
plt.grid(False)
plt.show()
